# %%
from matplotlib import pyplot as plt
import numpy as np

print(plt.draw_all.__doc__)
# Out:
#         Redraw all stale managed figures, or, if *force* is True, all managed
#         figures.

# %%
plt.plot(np.random.random(30),
         np.random.random(30))

plt.draw_all()
