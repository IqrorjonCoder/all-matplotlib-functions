# %%
from matplotlib import pyplot as plt

print(plt.delaxes.__doc__)
# Out:
#     Remove an `~.axes.Axes` (defaulting to the current axes) from its figure.

# %%
fig, axes = plt.subplots(2,1)

axes[0].plot([1,2,3],
             [3,1,2])

plt.delaxes(axes[1])

plt.show()
