# %%
from matplotlib import pyplot as plt

print(plt.Circle.__doc__)
# Out:
#     A circle patch.

# %%
first = plt.Circle((5,5), 1, color='red')
fig, axes = plt.subplots()

axes.add_patch(first)

axes.set_ylim(11)
axes.set_xlim(11)
plt.show()
