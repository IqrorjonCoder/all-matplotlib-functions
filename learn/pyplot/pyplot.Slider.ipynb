# %%
from matplotlib import pyplot as plt
import numpy as np

print(plt.Slider.__doc__)
# Out:
#     A slider representing a floating point range.
#
#     Create a slider from *valmin* to *valmax* in Axes *ax*. For the slider to
#     remain responsive you must maintain a reference to it. Call
#     :meth:`on_changed` to connect to the slider event.
#
#     Attributes
#     ----------
#     val : float
#         Slider value.

# %%
# please run the codes in xxx.py python file using terminal
# Not with jupyter

def simple_func(val):
    # print(dir(val))
    # print(val.as_integer_ratio)
    # print(val.bit_length)
    # print(val.conjugate)
    # print(val.denominator)
    # print(val.from_bytes)
    # print(val.imag)
    # print(val.numerator)
    # print(val.real)
    # print(val.to_bytes)
    ax.cla()
    ax.scatter(np.random.random(val.real),
               np.random.random(val.real))


fig, ax = plt.subplots()

ax.scatter([1, 2, 3],
           [2, 1, 3])

x = plt.Slider(plt.axes([0.3, 0.01, 0.6, 0.03]), label='simple', valmin=0, valmax=20, valinit=3, valstep=1)
x.on_changed(simple_func)
plt.show()
