# %%
from matplotlib import pyplot as plt

print(plt.get_plot_commands.__doc__)
# Out:
#     Get a sorted list of all of the plotting commands.

# %%
for i, v in enumerate(plt.get_plot_commands()):
    print(i, v)
# Out:
# 0 acorr
# 1 angle_spectrum
# 2 annotate
# 3 arrow
# 4 autoscale
# 5 axes
# 6 axhline
# 7 axhspan
# 8 axis
# 9 axline
# 10 axvline
# 11 axvspan
# 12 bar
# 13 bar_label
# 14 barbs
# 15 barh
# 16 box
# 17 boxplot
# 18 broken_barh
# 19 cla
# 20 clabel
# 21 clf
# 22 clim
# 23 close
# 24 cohere
# 25 colorbar
# 26 contour
# 27 contourf
# 28 csd
# 29 delaxes
# 30 draw
# 31 draw_if_interactive
# 32 errorbar
# 33 eventplot
# 34 figimage
# 35 figlegend
# 36 fignum_exists
# 37 figtext
# 38 figure
# 39 fill
# 40 fill_between
# 41 fill_betweenx
# 42 findobj
# 43 gca
# 44 gcf
# 45 gci
# 46 get
# 47 get_cmap
# 48 get_figlabels
# 49 get_fignums
# 50 getp
# 51 grid
# 52 hexbin
# 53 hist
# 54 hist2d
# 55 hlines
# 56 imread
# 57 imsave
# 58 imshow
# 59 install_repl_displayhook
# 60 ioff
# 61 ion
# 62 isinteractive
# 63 legend
# 64 locator_params
# 65 loglog
# 66 magnitude_spectrum
# 67 margins
# 68 matshow
# 69 minorticks_off
# 70 minorticks_on
# 71 pause
# 72 pcolor
# 73 pcolormesh
# 74 phase_spectrum
# ...
