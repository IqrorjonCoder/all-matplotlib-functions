# %%
from matplotlib import pyplot as plt
import numpy as np

print(plt.clf.__doc__)
# Out:
# Clear the current figure.

# %%
fig, axes = plt.subplots(2,1)

axes[0].plot(np.random.random(20))
axes[1].plot(np.random.random(20))

# fig.clf() # without clf()

plt.show()

# %%
fig, axes = plt.subplots(2,1)

axes[0].plot(np.random.random(20))
axes[1].plot(np.random.random(20))

fig.clf() # with clf()

plt.show()
