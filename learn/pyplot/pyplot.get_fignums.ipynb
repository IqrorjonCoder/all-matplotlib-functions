# %%
from matplotlib import pyplot as plt

print(plt.get_fignums.__doc__)
# Out:
# Return a list of existing figure numbers.

# %%
fig, ax = plt.subplots()
ax.plot([1,2], [2,3])
plt.show()

print(plt.get_fignums())
# Out:
# []
