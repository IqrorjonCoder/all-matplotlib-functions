# %%
from matplotlib import pyplot as plt
import numpy as np

data = np.random.randint(1,10,15)*5.3

plt.acorr(data)

plt.title("Auto-corralation!")

plt.xlabel("x-label")
plt.ylabel("y-label")

plt.show()
print(data)
# Out:
# [26.5 47.7 10.6 10.6 26.5 37.1  5.3 37.1 31.8 26.5  5.3 10.6 37.1 42.4
#  37.1]
