# %%
from matplotlib import pyplot as plt

print(plt.cla.__doc__)
# Out:
# Clear the current axes.

# %%
import numpy as np

fig, axes = plt.subplots(2,1)

axes[0].plot(np.random.random(50))
axes[0].cla() #clear the current axes


axes[1].plot(np.random.random(50))

plt.show()
