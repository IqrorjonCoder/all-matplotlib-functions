# %%
from matplotlib import pyplot as plt

# plt.Arrow(x=1.0, y=1.0,dx=2.0,dy=2.0,width=0.1,
#           head_length=0.5,
#           head_width=0.4,
#           )
plt.arrow(x=1.0, y=1.0,dx=2.0,dy=2.0,width=0.1,
          head_length=0.5,
          head_width=0.4,
          )
# print(plt.Arrow.__doc__)
