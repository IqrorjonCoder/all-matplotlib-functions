# %%
from matplotlib import pyplot as plt
import numpy as np

print(plt.subplot_tool.__doc__)
# Out:
#     Launch a subplot tool window for a figure.
#
#     Returns
#     -------
#     `matplotlib.widgets.SubplotTool`

# %%
fig, axs = plt.subplots()

axs.plot(np.random.random((10, 10)))

plt.subplot_tool()

fig.suptitle('matplotlib.pyplot.subplot_tool() Example')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       1 fig, axs = plt.subplots()
#       3 axs.plot(np.random.random((10, 10)))
# ----> 5 plt.subplot_tool()
#       7 fig.suptitle('matplotlib.pyplot.subplot_tool() Example')
#       8 plt.show()
#
# File ~/PycharmProjects/all matplotlib functions/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:1665, in subplot_tool(targetfig)
#    1663     return tb.trigger_tool("subplots")
#    1664 else:
# -> 1665     raise ValueError("subplot_tool can only be launched for figures with "
#    1666                      "an associated toolbar")
#
# ValueError: subplot_tool can only be launched for figures with an associated toolbar
