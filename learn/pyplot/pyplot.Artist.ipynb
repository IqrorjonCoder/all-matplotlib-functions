# %%
from matplotlib import pyplot as plt

functions = [i for i in dir(plt.Artist) if i[0] != '_']

for i,v in enumerate(functions):
    print(i+1, v)
# Out:
# 1 add_callback
# 2 axes
# 3 contains
# 4 convert_xunits
# 5 convert_yunits
# 6 draw
# 7 findobj
# 8 format_cursor_data
# 9 get_agg_filter
# 10 get_alpha
# 11 get_animated
# 12 get_children
# 13 get_clip_box
# 14 get_clip_on
# 15 get_clip_path
# 16 get_cursor_data
# 17 get_figure
# 18 get_gid
# 19 get_in_layout
# 20 get_label
# 21 get_mouseover
# 22 get_path_effects
# 23 get_picker
# 24 get_rasterized
# 25 get_sketch_params
# 26 get_snap
# 27 get_tightbbox
# 28 get_transform
# 29 get_transformed_clip_path_and_affine
# 30 get_url
# 31 get_visible
# 32 get_window_extent
# 33 get_zorder
# 34 have_units
# 35 is_transform_set
# 36 mouseover
# 37 pchanged
# 38 pick
# 39 pickable
# 40 properties
# 41 remove
# 42 remove_callback
# 43 set
# 44 set_agg_filter
# 45 set_alpha
# 46 set_animated
# 47 set_clip_box
# 48 set_clip_on
# 49 set_clip_path
# 50 set_figure
# 51 set_gid
# 52 set_in_layout
# 53 set_label
# 54 set_mouseover
# 55 set_path_effects
# 56 set_picker
# 57 set_rasterized
# 58 set_sketch_params
# 59 set_snap
# 60 set_transform
# 61 set_url
# 62 set_visible
# 63 set_zorder
# 64 stale
# 65 sticky_edges
# 66 update
# 67 update_from
# 68 zorder

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, axes = plt.subplots()

axes.plot([1,2,3,1,2,3,1,3,4,2],
             [6,3,3,2,4,2,1,4,5,2])

plt.Artist.set(axes, title='simplee Artist',
               xlabel='x-label',
               ylabel='y-label')


fig.show()
# Out:
# /tmp/ipykernel_2394/2326563304.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
